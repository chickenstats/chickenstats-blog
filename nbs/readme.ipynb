# %% [markdown]
# # chickenstats-blog
#
# > Blog for chickenstats. Data analysis and visualizations in Python

# %% [markdown]
# ![](https://raw.githubusercontent.com/chickenstats/chickenstats-blog/refs/heads/main/nbs/images/site/hero/hero_transparent.png)

# %% [markdown]
# Welcome to the blog for chickenstats. Here you can find examples for the `chickenstats` library and the code
# used for the [chicken and stats](https://chickenandstats.com) newsletter

# %% [markdown]
# # Projects
#
# Follow the links below to the different projects in the chickenstats portfolio

# %% [markdown]
# :::{.grid}
# :::{.g-col-12 .g-col-md-6}
# ### chickenstats
# :::
# :::{.g-col-12 .g-col-md-6}
# ### chickenstats-xg
# :::
# :::{.g-col-12 .g-col-md-6}
# ### chickenstats-api
# :::
# :::{.g-col-12 .g-col-md-6}
# ### chicken and stats
# :::
# :::

# %% [markdown]
# # Blog
#
# Read posts for the respective topics

# %% [markdown]
# :::{.grid layout-valign="center"}
# :::{.g-col-12 .g-col-md-4}
# ### Nashville Predators
# ![](https://raw.githubusercontent.com/chickenstats/chickenstats-blog/refs/heads/main/nbs/images/logos/nashville_predators.png)
# :::
# :::{.g-col-12 .g-col-md-4}
# ### Tennessee Titans
# ![](https://raw.githubusercontent.com/chickenstats/chickenstats-blog/refs/heads/main/nbs/images/logos/tennessee_titans.png)
# :::
# :::{.g-col-12 .g-col-md-4}
# ### Tennessee Volunteers
# ![](https://raw.githubusercontent.com/chickenstats/chickenstats-blog/refs/heads/main/nbs/images/logos/tennessee_volunteers.png)
# :::
# :::

# %% [markdown]
# # About

# %% [markdown]
# :::{.grid}
# :::{.g-col-12 .g-col-md-4}
# ![](https://raw.githubusercontent.com/chickenstats/chickenstats-blog/refs/heads/main/nbs/images/site/avatar_transparent.png){height=200px fig-align="center"}
# :::
# :::{.g-col-12 .g-col-md-8}
# ### About me
#
# I'm chicken.
# :::
# :::
